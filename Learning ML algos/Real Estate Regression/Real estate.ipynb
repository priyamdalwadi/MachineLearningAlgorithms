# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
# Out:
# D:\priyam\pythontools\envs\Tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\priyam\pythontools\envs\Tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\priyam\pythontools\envs\Tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
df = pd.read_csv('Real estate.csv')

# %%
df.corr()['Y house price of unit area']
# Out:
# No                                       -0.028587
# X1 transaction date                       0.087491
# X2 house age                             -0.210567
# X3 distance to the nearest MRT station   -0.673613
# X4 number of convenience stores           0.571005
# X5 latitude                               0.546307
# X6 longitude                              0.523287
# Y house price of unit area                1.000000
# Name: Y house price of unit area, dtype: float64

# %%
fig,ax = plt.subplots(figsize = (8,6))

ax.scatter(df['X6 longitude'],df['X5 latitude'],c = df['Y house price of unit area']);
ax.set(xlabel = 'longitude', ylabel = 'Y house price of unit area')

ax.axhline(df['X5 latitude'].mean(),ls = '--')
ax.axvline(df['X6 longitude'].mean(),ls = '--')
print(df['X5 latitude'].mean())
print(df['X6 longitude'].mean())
# Out:
# 24.969030072463745
# 121.53336108695667

# %% [raw]
# 121.48 - 121.51
# 121.51 - 121.53
# 121.53 - 121.55
# 121.55

# %%
df.drop('No', axis= 1 ,inplace= True)

# %%
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %%
fig,ax = plt.subplots(figsize = (8,6))

ax.scatter(df['X1 transaction date'],df['Y house price of unit area']);
ax.set(xlabel = 'transsaction', ylabel = 'Y house price of unit area')
ax.axhline(df['Y house price of unit area'].mean(),ls = '--')
ax.axvline(df['X1 transaction date'].mean(),ls = '--')
print(df['Y house price of unit area'].mean())
print(df['X1 transaction date'].mean())
# Out:
# 37.98019323671498
# 2013.1489710144933

# %%
df['X5 latitude'].unique()
# Out:
# array([24.98298, 24.98034, 24.98746, 24.97937, 24.96305, 24.97933,
#        24.98042, 24.95095, 24.96731, 24.97349, 24.97433, 24.96515,
#        24.96108, 24.99156, 24.9824 , 24.97744, 24.97544, 24.9675 ,
#        24.96772, 24.96314, 24.97528, 24.95204, 24.97353, 24.97542,
#        24.98085, 24.95593, 24.97419, 24.97563, 24.94826, 24.98281,
#        24.97841, 24.98419, 25.01459, 24.96386, 24.97201, 24.98203,
#        24.94155, 24.94297, 24.98748, 24.97445, 24.97015, 24.9703 ,
#        24.94684, 24.94925, 24.974  , 24.95402, 24.94968, 24.97254,
#        24.95744, 24.95776, 24.96365, 24.97585, 24.96303, 24.97635,
#        24.96571, 24.96674, 24.97964, 24.97587, 24.98343, 24.97723,
#        24.96322, 24.97598, 24.95182, 24.96427, 24.96725, 24.96056,
#        24.96735, 24.96853, 24.9512 , 24.98573, 24.94783, 24.9748 ,
#        24.98569, 24.9492 , 24.9663 , 24.97746, 24.98872, 24.97371,
#        24.95618, 24.96398, 24.97707, 24.9726 , 24.96299, 24.97701,
# ...

# %%
df.columns
# Out:
# Index(['X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
X = df.drop('Y house price of unit area',axis = 1).values
y = df['Y house price of unit area'].values

# %%
type(X)
# Out:
# numpy.ndarray

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.30, random_state=42)

# %%
df['X5 latitude']
# Out:
# 0      24.98298
# 1      24.98034
# 2      24.98746
# 3      24.98746
# 4      24.97937
#          ...
# 409    24.94155
# 410    24.97433
# 411    24.97923
# 412    24.96674
# 413    24.97433
# Name: X5 latitude, Length: 414, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
X_train = scalar.fit_transform(X_train)
X_test = scalar.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# k_fold = KFold(n_splits=10,random_state=0, shuffle= True)

# %%
# clf = KNeighborsClassifier(n_neighbors=13)
# score = 'accuracy'
# score = cross_val_score(clf,X_train,y_train,cv=k_fold,n_jobs=-1,scoring=score)

# %%
y_pred = lr.predict(X_test)
y_pred[:20]
# Out:
# array([47.55430212, 41.08372744, 44.25551663, 40.51685112, 27.43467608,
#        45.85435624, 44.70296876, 46.57752144, 23.86072119, 54.35199522,
#        34.63011363, 36.34958785, 37.34518438, 23.49428018, 36.02735916,
#        34.56828629, 44.01823263, 45.04246804, 29.9554971 , 43.96338099])

# %%
y_test[:20]
# Out:
# array([45.1, 42.3, 52.2, 37.3, 22.8, 36.3, 53. , 51.4, 16.1, 59. , 30.6,
#        30.7, 35.6, 13.7, 62.9, 30.5, 41.9, 54.4, 29.5, 43.7])
